# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananta-09/Python_Basic_Assignment/blob/main/Function_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.What is the difference between a function and a method in Python?
#
# Ans:
# Function: A block of code that runs when called, defined outside of a class. Functions can be called directly using their name.
# Method: A function that is associated with an object, defined inside a class. It requires an instance of the class to be called.
#
# 2.Explain the concept of function arguments and parameters in Python?
#
# Ans:
# Parameters: Variables listed inside the function's definition.
# Arguments: Values passed to the function when calling it.
#
# 3.What are the different ways to define and call a function in Python?
#
# Ans:
# Standard function definition using def: .
# We can define a function with default arguments.
# Positional *args Accepts multiple positional arguments.
# Keyword **kwargs Accepts multiple keyword arguments.
#
# 4.What is the purpose of the return statement in a Python function?
#
# Ans:
# The return statement exits the function and gives back a result or None if no value is specified. It allows the function to output a value that can be used later.
#
# 5.What are iterators in Python and how do they differ from iterables?
#
# Ans:
# Iterable: An object capable of returning its members one at a time like lists, tuples.
# Iterator: An object representing a stream of data that can be iterated over using next() until the end is reached. It is obtained by calling iter() on an iterable.
#
# 6.Explain the concept of generators in Python and how they are defined?
#
# Ans:
# Generators are a special type of iterator, defined with a function using yield instead of return.It allows the generation of a series of values one value at a time.
#
# 7.What are the advantages of using generators over regular functions?
#
# Ans:
# It yield one item at a time, making them useful for large datasets.
# Values are generated only when needed.
# Simple syntax for writing iterators.
#
# 8.What is a lambda function in Python and when is it typically used?
#
# Ans:
# A lambda function is an anonymous, one-line function defined with the lambda keyword. It is often used for short, simple functions without the need for def.
#
# 9.Explain the purpose and usage of the `map()` function in Python?
#
# Ans:
# The map() function applies a given function to all items in an iterable and returns a map object which is an iterator.
#
# 10.What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# Ans:
# map(): Applies a function to all items in an iterable and returns the result.
# filter(): Filters items based on a function,returns only True items.
# reduce(): Reduces an iterable to a single value using a binary function.
#
# 11.Using pen & Paper write the internal mechanism for sum operation using reduce function on this givenlist:[47,11,42,13];
#
# Ans:
# from functools import reduce
#
# # Step 1: Define the list of numbers
# numbers = [47, 11, 42, 13]
#
# # Step 2: Define the lambda function for summation
# sum_function = lambda x, y: x + y
#
# # Step 3: Apply reduce to sum the list
# total_sum = reduce(sum_function, numbers)
#
# # Step 4: Output the result
# print("The sum of the list is:", total_sum)
#
#
# (from functools import reduce: Imports the reduce() function to apply a function cumulatively to the list.
#
# numbers = [47, 11, 42, 13]: Defines the list of numbers.
#
# sum_function = lambda x, y: x + y: This lambda function adds two numbers, x and y.
#
# total_sum = reduce(sum_function, numbers): The reduce() function adds the numbers step-by-step:
#
# Step 1: 47 + 11 = 58
# Step 2: 58 + 42 = 100
# Step 3: 100 + 13 = 113
# print("The sum of the list is:", total_sum): Prints the final result.)

# %%
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
#the list?
def sum_of_evens(numbers):
    return sum(num for num in numbers if num % 2 == 0)

numbers = [1, 2, 3, 4, 5, 6]
print(sum_of_evens(numbers))

#2.Create a Python function that accepts a string and returns the reverse of that string?
def reverse_string(s):
    return s[::-1]

# Example usage:
s = "Ananta"
print(reverse_string(s))

#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
#each number?
def square_numbers(numbers):
    return [num ** 2 for num in numbers]

# Example usage:
numbers = [1, 2, 3, 4]
print(square_numbers(numbers))

#4.Write a Python function that checks if a given number is prime or not from 1 to 200?
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True

primes = [num for num in range(1, 201) if is_prime(num)]
print(primes)

#5.Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
#terms?
class FibonacciIterator:
    def __init__(self, n):
        self.n = n
        self.a, self.b = 0, 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n:
            raise StopIteration
        self.count += 1
        fib = self.a
        self.a, self.b = self.b, self.a + self.b
        return fib

# Example usage:
fib_iter = FibonacciIterator(10)
for num in fib_iter:
    print(num, end=" ")

#6.Write a generator function in Python that yields the powers of 2 up to a given exponent?
def powers_of_2(exponent):
    for i in range(exponent + 1):
        yield 2 ** i

# Example usage:
for power in powers_of_2(5):
    print(power, end=" ")

#7. Implement a generator function that reads a file line by line and yields each line as a string?
def read_file_line_by_line(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line.strip()

#8.Use a lambda function in Python to sort a list of tuples based on the second element of each tuple?
tuples_list = [(1, 3), (4, 1), (2, 2)]
sorted_tuples = sorted(tuples_list, key=lambda x: x[1])

# Example usage:
print(sorted_tuples)

#9.Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit?
celsius = [0, 10, 20, 30, 40]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))

# Example usage:
print(fahrenheit)

#10.Create a Python program that uses `filter()` to remove all the vowels from a given string?
def remove_vowels(string):
    vowels = "aeiouAEIOU"
    return ''.join(filter(lambda char: char not in vowels, string))

# Example usage:
string = "Hello World"
print(remove_vowels(string))

#11 Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this?
# List of orders
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

# Calculate the total price for each order, increasing by 10 if the total is less than 100
result = list(map(lambda order: (order[0], order[2] * order[3] if order[2] * order[3] >= 100 else order[2] * order[3] + 10), orders))

print(result)
